# %%
import torch
import matplotlib.pyplot as plt

# %%
states, actions, rewards, dones = torch.load('intersimple-expert-data-setobs2.pt')
#states, actions, rewards, dones = torch.load('intersimple-expert-data-minobs.pt')
print('states', states.shape, states.dtype)
print('actions', actions.shape, actions.dtype)
print('rewards', rewards.shape, rewards.dtype)
print('dones', dones.shape, dones.dtype)
# Out:
# states torch.Size([2048, 200, 5, 6]) torch.float32
# actions torch.Size([2048, 200, 1]) torch.float32
# rewards torch.Size([2048, 200]) torch.float32
# dones torch.Size([2048, 200]) torch.bool

# %%
i = 52
plt.plot(actions[i, ~dones[i, :], 0])

# %%
for a, d in zip(actions.squeeze(), dones):
    plt.plot(a[~d])

plt.show()

# %%
plt.plot(states[:, :, 0, 0].T)
plt.show()

# %%
plt.hist(states[~dones][:, 0, 0].numpy(), density=True, bins=100)
plt.show()
